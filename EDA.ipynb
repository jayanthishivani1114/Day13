# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\VIJAYAKUMARA\OneDrive\Documents\Downloads\housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.longitude)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.longitude,kde=True)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df.latitude)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(df.housing_median_age)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.pairplot(df)
plt.show()

# %%
###Right skew distribution

# %%
data=np.random.exponential(scale=2,size=1000)
df=pd.DataFrame({"longitude":data})
df.head()
# Out:
#    longitude
# 0   2.483841
# 1   9.914882
# 2   0.502921
# 3   5.661591
# 4   1.733439

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.longitude)
plt.show()

# %%
df.longitude.skew()
# Out:
# np.float64(1.8534162683241309)

# %%
from scipy.stats import boxcox
df["updated_longitude"],lambda_val=boxcox(df.longitude)
df.head()
# Out:
#    longitude  updated_longitude
# 0   2.483841           1.020955
# 1   9.914882           3.092842
# 2   0.502921          -0.631788
# 3   5.661591           2.167495
# 4   1.733439           0.589512

# %%
lambda_val
# Out:
# np.float64(0.24869042286789325)

# %%
df.updated_longitude.skew()
# Out:
# np.float64(-0.0445073570702281)

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.updated_longitude)
plt.show()

# %%
###left skewed distribution

# %%
data=np.random.exponential(scale=2,size=1000)
data=10-data
df=pd.DataFrame({"longitude2":data})
df.head()
# Out:
#    longitude2
# 0    7.046098
# 1    9.707644
# 2    6.584890
# 3    6.868867
# 4    8.758616

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.longitude2)
plt.show()

# %%
df.longitude2.skew()
# Out:
# np.float64(-2.003588981411582)

# %%
df["reflex_longitude2"]=(df.longitude2.max()-df.longitude2)+1
df.head()
# Out:
#    longitude2  reflex_longitude2
# 0    7.046098           3.953763
# 1    9.707644           1.292216
# 2    6.584890           4.414970
# 3    6.868867           4.130994
# 4    8.758616           2.241245

# %%
max(df.reflex_longitude2), min(df.reflex_longitude2)
# Out:
# (18.24290499707018, 1.0)

# %%
df["transformed_longitude2"]=np.log(df.reflex_longitude2)+1
df.transformed_longitude2.skew()
# Out:
# np.float64(0.41903973116579135)

# %%
plt.figure(figsize=(6,4))
sns.histplot(df.longitude2)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
df=pd.read_csv(r"C:\Users\VIJAYAKUMARA\OneDrive\Documents\Downloads\housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['longitude','latitude']] = scaler.fit_transform(df[['longitude','latitude']])
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.327835  1.052548                41.0        880.0           129.0
# 1  -1.322844  1.043185                21.0       7099.0          1106.0
# 2  -1.332827  1.038503                52.0       1467.0           190.0
# 3  -1.337818  1.038503                52.0       1274.0           235.0
# 4  -1.337818  1.038503                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['longitude','latitude']] = scaler.fit_transform(df[['longitude','latitude']])
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0   0.211155  0.567481                41.0        880.0           129.0
# 1   0.212151  0.565356                21.0       7099.0          1106.0
# 2   0.210159  0.564293                52.0       1467.0           190.0
# 3   0.209163  0.564293                52.0       1274.0           235.0
# 4   0.209163  0.564293                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
from sklearn.preprocessing import RobustScaler
scaler = StandardScaler()
df[['longitude','latitude']] = scaler.fit_transform(df[['longitude','latitude']])
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0  -1.327835  1.052548                41.0        880.0           129.0
# 1  -1.322844  1.043185                21.0       7099.0          1106.0
# 2  -1.332827  1.038503                52.0       1467.0           190.0
# 3  -1.337818  1.038503                52.0       1274.0           235.0
# 4  -1.337818  1.038503                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.figure()
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
df["housing_median_age"]=scaler.fit_transform(df[["housing_median_age"]])
df["total_rooms"]=scaler.fit_transform(df[["total_rooms"]])
df["total_bedrooms"]=scaler.fit_transform(df[["total_bedrooms"]])
df["population"]=scaler.fit_transform(df[["population"]])
df["median_income"]=scaler.fit_transform(df[["median_income"]])
df["median_house_value"]=scaler.fit_transform(df[["median_house_value"]])

# %%
x=df[["housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
y=df["median_house_value"]

# %%
x.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0            0.982143    -0.804819       -0.970325   -0.974429       126.0
# 1           -0.607019     2.045890        1.348276    0.861439      1138.0
# 2            1.856182    -0.535746       -0.825561   -0.820777       177.0
# 3            1.856182    -0.624215       -0.718768   -0.766028       219.0
# 4            1.856182    -0.462404       -0.611974   -0.759847       259.0
#
#    median_income
# 0       2.344766
# 1       2.332238
# 2       1.782699
# 3       0.932968
# 4      -0.012881

# %%
x.shape,y.shape
# Out:
# ((20640, 6), (20640,))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((16512, 6), (4128, 6))

# %%
y_train.shape, y_test.shape
# Out:
# ((16512,), (4128,))

# %%
from sklearn.linear_model import LinearRegression, Ridge,Lasso
from sklearn.metrics import mean_squared_error, r2_score

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_,model.coef_
# Out:
# (np.float64(-0.5503203817735299),
#  array([ 0.20689504, -0.3781639 ,  0.37225745, -0.34987729,  0.00110085,
#          0.78957398]))

# %%
predicted_val=model.predict(x_train)
predicted_val
# Out:
# array([-0.32321047,  0.71763524, -0.36376293, ..., -0.22021703,
#         0.38992058,  0.70480822], shape=(16512,))

# %%
mean_squared_error(y_train,predicted_val)
# Out:
# 0.4316060835070305

# %%
r2_score(y_train,predicted_val)
# Out:
# 0.5700818543102877

# %%
y_train-predicted_val
# Out:
# 14196   -0.576809
# 8267     0.801040
# 17445    0.066900
# 14265   -0.205253
# 2271    -1.048860
#            ...
# 11284   -0.804113
# 11964   -0.469138
# 5390     0.352324
# 860      0.274282
# 15795    0.319035
# Name: median_house_value, Length: 16512, dtype: float64

# %%
##Task1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv(r"C:\Users\VIJAYAKUMARA\OneDrive\Documents\Downloads\housing.csv")
df
# Histogram with KDE
sns.histplot(data=df, x="housing_median_age", kde=True, bins=30)
plt.title("Distribution of Housing Prices")
plt.show()

# %%
from scipy.stats import skew, kurtosis
housing_median_age_skew = skew(df["housing_median_age"])
housing_median_age_kurt = kurtosis(df["housing_median_age"])
print("Skewness:",housing_median_age_skew)
print("Kurtosis:",housing_median_age_kurt)
# Out:
# Skewness: 0.060326253016611
# Kurtosis: -0.8007255995444988

# %%
sns.countplot(data=df, x="housing_median_age")
plt.title("Count housing_median_age")
plt.xticks(rotation=45)
plt.show()

# %%
###Task2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=df, x="households", y="population")
plt.title("households vs. population")
plt.show()

# %%
sns.boxplot(data=df, x="households", y="population")
plt.title("Price Distribution by population")
plt.xticks(rotation=45)
plt.show()

# %%
###Task3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation matrix
corr_matrix = df.corr(numeric_only=True)

# %%
# Heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
sns.boxplot(data=df, y="population")
plt.title("Outliers in Housing Prices")
plt.show()
